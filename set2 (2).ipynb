# %%
sentence = input("Enter a sentence: ")
words = sentence.split()
freq = {}
for word in words:
    if word in freq:
        freq[word] = freq[word] + 1
    else:
        freq[word] = 1

print("Word Frequencies:")
for key in freq:
    print(key, ":", freq[key])
# Out:
# Enter a sentence:  python is easy or python is hard
# Word Frequencies:
# python : 2
# is : 2
# easy : 1
# or : 1
# hard : 1

# %%
d1 = {'a': 10, 'b': 20, 'c': 30}
d2 = {'b': 15, 'c': 25, 'd': 40}
result = {}
for key in d1:
    result[key] = d1[key]
for key in d2:
    if key in result:
        result[key] = result[key] + d2[key]
    else:
        result[key] = d2[key]

print("Merged Dictionary:")
for key in result:
    print(key, ":", result[key])
# Out:
# Merged Dictionary:
# a : 10
# b : 35
# c : 55
# d : 40
