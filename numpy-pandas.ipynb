# %%
# !pip install pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.0.3)
# Requirement already satisfied: numpy in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 3.0.3
# NumPy version: 2.4.6

# %%
import pandas as pd
import numpy as np

# Create dataset
data = {
    "Name": ["Rahul", "Amit", "Neha", "Riya", "Karan", "Rahul", "Simran", "Priya", "Arjun", "Pooja"],
    "Branch": ["CSE", "ECE", "CSE", "ECE", "MECH", "CSE", "MECH", "ECE", "CSE", "MECH"],
    "Marks": [85, 78, np.nan, 70, 88, 85, 90, np.nan, 95, 60],
    "Age": [22, 25, 21, 23, np.nan, 22, 24, 25, 22, np.nan]
}

df = pd.DataFrame(data)

# Save to CSV
df.to_csv("students_lab.csv", index=False)

print(df)
# Out:
#      Name Branch  Marks   Age
# 0   Rahul    CSE   85.0  22.0
# 1    Amit    ECE   78.0  25.0
# 2    Neha    CSE    NaN  21.0
# 3    Riya    ECE   70.0  23.0
# 4   Karan   MECH   88.0   NaN
# 5   Rahul    CSE   85.0  22.0
# 6  Simran   MECH   90.0  24.0
# 7   Priya    ECE    NaN  25.0
# 8   Arjun    CSE   95.0  22.0
# 9   Pooja   MECH   60.0   NaN

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\aceec

# %%
df = pd.read_csv("students_lab.csv")

# %%
df.head()
# Out:
#     Name Branch  Marks   Age
# 0  Rahul    CSE   85.0  22.0
# 1   Amit    ECE   78.0  25.0
# 2   Neha    CSE    NaN  21.0
# 3   Riya    ECE   70.0  23.0
# 4  Karan   MECH   88.0   NaN

# %%
df.tail()
# Out:
#      Name Branch  Marks   Age
# 5   Rahul    CSE   85.0  22.0
# 6  Simran   MECH   90.0  24.0
# 7   Priya    ECE    NaN  25.0
# 8   Arjun    CSE   95.0  22.0
# 9   Pooja   MECH   60.0   NaN

# %%
df.head(7)
# Out:
#      Name Branch  Marks   Age
# 0   Rahul    CSE   85.0  22.0
# 1    Amit    ECE   78.0  25.0
# 2    Neha    CSE    NaN  21.0
# 3    Riya    ECE   70.0  23.0
# 4   Karan   MECH   88.0   NaN
# 5   Rahul    CSE   85.0  22.0
# 6  Simran   MECH   90.0  24.0

# %%
df.describe()
# Out:
#            Marks        Age
# count   8.000000   8.000000
# mean   81.375000  23.000000
# std    11.513191   1.511858
# min    60.000000  21.000000
# 25%    76.000000  22.000000
# 50%    85.000000  22.500000
# 75%    88.500000  24.250000
# max    95.000000  25.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     str
#  1   Branch  10 non-null     str
#  2   Marks   8 non-null      float64
#  3   Age     8 non-null      float64
# dtypes: float64(2), str(2)
# memory usage: 452.0 bytes

# %%
df["Name"]
# Out:
# 0     Rahul
# 1      Amit
# 2      Neha
# 3      Riya
# 4     Karan
# 5     Rahul
# 6    Simran
# 7     Priya
# 8     Arjun
# 9     Pooja
# Name: Name, dtype: str

# %%
df[df["Age"] > 23]
# Out:
#      Name Branch  Marks   Age
# 1    Amit    ECE   78.0  25.0
# 6  Simran   MECH   90.0  24.0
# 7   Priya    ECE    NaN  25.0

# %%
df1=df[df["Age"] > 23]
print(df1)
# Out:
#      Name Branch  Marks   Age
# 1    Amit    ECE   78.0  25.0
# 6  Simran   MECH   90.0  24.0
# 7   Priya    ECE    NaN  25.0

# %%
df1= df1.rename(columns={"Age": "Years"})

# %%
df1
# Out:
#      Name Branch  Marks  Years
# 1    Amit    ECE   78.0   25.0
# 6  Simran   MECH   90.0   24.0
# 7   Priya    ECE    NaN   25.0

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Name Branch  Marks   Age
# 0   Rahul    CSE   85.0  22.0
# 1    Amit    ECE   78.0  25.0
# 2    Neha    CSE    NaN  21.0
# 3    Riya    ECE   70.0  23.0
# 4   Karan   MECH   88.0   NaN
# 6  Simran   MECH   90.0  24.0
# 7   Priya    ECE    NaN  25.0
# 8   Arjun    CSE   95.0  22.0
# 9   Pooja   MECH   60.0   NaN

# %%
df.isnull()
# Out:
#     Name  Branch  Marks    Age
# 0  False   False  False  False
# 1  False   False  False  False
# 2  False   False   True  False
# 3  False   False  False  False
# 4  False   False  False   True
# 6  False   False  False  False
# 7  False   False   True  False
# 8  False   False  False  False
# 9  False   False  False   True

# %%
df.isnull().sum()
# Out:
# Name      0
# Branch    0
# Marks     2
# Age       2
# dtype: int64

# %%
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#      Name Branch      Marks        Age
# 0   Rahul    CSE  85.000000  22.000000
# 1    Amit    ECE  78.000000  25.000000
# 2    Neha    CSE  80.857143  21.000000
# 3    Riya    ECE  70.000000  23.000000
# 4   Karan   MECH  88.000000  23.142857
# 6  Simran   MECH  90.000000  24.000000
# 7   Priya    ECE  80.857143  25.000000
# 8   Arjun    CSE  95.000000  22.000000
# 9   Pooja   MECH  60.000000  23.142857

# %%
# Returns a single True or False for the entire DataFrame
df.isnull().values.any()
# Out:
# np.False_

# %%
df.groupby("Branch")["Marks"].mean()
# Out:
# Branch
# CSE     86.952381
# ECE     76.285714
# MECH    79.333333
# Name: Marks, dtype: float64

# %%
df.groupby("Branch")["Marks"].agg(["mean", "max", "min", "count"])
# Out:
#              mean        max        min  count
# Branch
# CSE     86.952381  95.000000  80.857143      3
# ECE     76.285714  80.857143  70.000000      3
# MECH    79.333333  90.000000  60.000000      3

# %%
import pandas as pd
raw_data = [
 ['Alice', 'Engineering', 'Senior', 110000, 15000],
 ['Bob', 'Marketing', 'Junior', 70000, 5000],
 ['Charlie', 'Engineering', 'Senior', 100000, 12000],
 ['David', 'Marketing', 'Senior', 95000, 8000],
 ['Eva', 'Engineering', 'Junior', 85000, 6000],
 ['Frank', 'Marketing', 'Junior', 6500]
]
df2 = pd.DataFrame(raw_data)

# %%
df2
# Out:
#          0            1       2       3        4
# 0    Alice  Engineering  Senior  110000  15000.0
# 1      Bob    Marketing  Junior   70000   5000.0
# 2  Charlie  Engineering  Senior  100000  12000.0
# 3    David    Marketing  Senior   95000   8000.0
# 4      Eva  Engineering  Junior   85000   6000.0
# 5    Frank    Marketing  Junior    6500      NaN

# %%
df2.columns = ['Employee', 'Team', 'Level', 'Salary', 'Bonus']

# %%
df2
# Out:
#   Employee         Team   Level  Salary    Bonus
# 0    Alice  Engineering  Senior  110000  15000.0
# 1      Bob    Marketing  Junior   70000   5000.0
# 2  Charlie  Engineering  Senior  100000  12000.0
# 3    David    Marketing  Senior   95000   8000.0
# 4      Eva  Engineering  Junior   85000   6000.0
# 5    Frank    Marketing  Junior    6500      NaN

# %%
columns = ["Employee", "Team", "Level", "Salary", "Bonus"]
df2 = pd.DataFrame(raw_data, columns=columns)

# %%
df2
# Out:
#   Employee         Team   Level  Salary    Bonus
# 0    Alice  Engineering  Senior  110000  15000.0
# 1      Bob    Marketing  Junior   70000   5000.0
# 2  Charlie  Engineering  Senior  100000  12000.0
# 3    David    Marketing  Senior   95000   8000.0
# 4      Eva  Engineering  Junior   85000   6000.0
# 5    Frank    Marketing  Junior    6500      NaN

# %%
df2['Team_Avg_Salary'] = df2.groupby('Team')['Salary'].transform('mean')

# %%
print(df2)
# Out:
#   Employee         Team   Level  Salary    Bonus  Team_Avg_Salary
# 0    Alice  Engineering  Senior  110000  15000.0     98333.333333
# 1      Bob    Marketing  Junior   70000   5000.0     57166.666667
# 2  Charlie  Engineering  Senior  100000  12000.0     98333.333333
# 3    David    Marketing  Senior   95000   8000.0     57166.666667
# 4      Eva  Engineering  Junior   85000   6000.0     98333.333333
# 5    Frank    Marketing  Junior    6500      NaN     57166.666667

# %%
summary_diff_math = df2.groupby('Team', as_index=False).agg({
 'Salary': 'mean',
 'Bonus': 'sum'
})
print(summary_diff_math)
# Out:
#           Team        Salary    Bonus
# 0  Engineering  98333.333333  33000.0
# 1    Marketing  57166.666667  13000.0

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ----------------------------------- ---- 8.4/9.3 MB 39.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 37.9 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 44.3 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 7.1/7.1 MB 45.1 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.2.0 pyparsing-3.3.2
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\aceec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import matplotlib.pyplot as plt
print("Matplotlib installed successfully!")
# Out:
# Matplotlib installed successfully!

# %%
import sys
print(sys.version)
# Out:
# 3.13.13 (tags/v3.13.13:01104ce, Apr  7 2026, 19:25:48) [MSC v.1944 64 bit (AMD64)]

# %%
import matplotlib.pyplot as plt
df_dept = df2.groupby('Team')['Salary'].mean()
df_dept.plot(kind="bar", color=["skyblue", "green"])
plt.title("Average Salary by Department")
plt.ylabel("Salary (rupee)")
plt.show()

# %%
df2["Total_Pay"] = df2["Salary"] + df2["Bonus"]
df2.plot(x="Employee", y="Total_Pay", kind="line", marker="*", color="lightblue")
plt.title("Total Pay per Employee")
plt.ylabel("Total Pay (Rupee)")
plt.show()

# %%
df2.plot(
 kind="scatter", x="Bonus", y="Salary", color="pink", s=100, marker="o")
plt.title("Salary vs. Bonus Correlation")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
import matplotlib.pyplot as plt
df2.plot(x='Employee', y='Salary', kind='bar',color="black")
plt.show()

# %%
df2.plot(x='Employee', y='Salary', kind='line', marker='o')
# Out:
# <Axes: xlabel='Employee'>

# %%
df2['Team'].value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: >

# %%
df2.groupby(['Team', 'Level'])['Salary'].mean().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='Team'>
