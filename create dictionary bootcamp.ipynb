# %%
students = {}

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter name: ")
    marks = int(input("Enter marks: "))

    students[name] = marks

print(students)
employees ={}
e=int(input("enter number of employees:"))
for j in range(e):
    emp =input("enter name:")
    salary = int(input("enter emp salary:"))
print("employee")
#updating
stud_name =input("enter a student name that you want to update marks:")
if stud_name in students:
    new_marks=int(input("enter new marks"))
    print(students)
#delete
del_name=input("enter a student name want to delete:")
if del_name in students:
    del students[del_name]
    print(students)
else:
    print("not found")
# Out:
# Enter number of students:  3
# Enter name:  radha
# Enter marks:  55
# Enter name:  janu
# Enter marks:  90
# Enter name:  dhoni
# Enter marks:  58
# {'radha': 55, 'janu': 90, 'dhoni': 58}
# enter number of employees: 3
# enter name: raju
# enter emp salary: 9000
# enter name: sathwik
# enter emp salary: 65000
# enter name: naveen
# enter emp salary: 18000
# employee
# enter a student name that you want to update marks: radha
# enter new marks 80
# {'radha': 55, 'janu': 90, 'dhoni': 58}
# enter a student name want to delete: janu
# {'radha': 55, 'dhoni': 58}
